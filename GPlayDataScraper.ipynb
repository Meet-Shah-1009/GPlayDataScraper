# %%
from google_play_scraper import app
from google_play_scraper import Sort, reviews_all
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
us_reviews = reviews_all(
    'co.go.fynd',#Paste your Google Play Store APP link here
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='in', # defaults to 'us'
    #sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
)

# %%
df2 = pd.DataFrame(np.array(us_reviews),columns=['review'])

# %%
df2 = df2.join(pd.DataFrame(df2.pop('review').tolist()))

# %%
df2
# Out:
#                                    reviewId            userName  \
# 0      326efb11-1e1c-40d0-91b3-44b782139102       Dolon Bachhar
# 1      5c8b7263-875a-4c84-b723-236b93de8402  arunachalam vinoth
# 2      8651fc51-041b-4b0b-8bf0-6145e0b32d71         Ruma Podder
# 3      2b5b4baf-0c04-4d49-8caa-4f8ce7e43b72     Tanusree Bhagat
# 4      30e647c0-15bc-4e4b-a715-684ce3ad1bb6            Itz Neer
# ...                                     ...                 ...
# 81569  2c43f36b-1874-44fa-a3fa-84510e11b6e2       A Google user
# 81570  9c9a10ec-2349-4e5c-83bd-7b2ec28bb8d3       A Google user
# 81571  3cfd9f85-4c3a-492b-950b-ba3ddf946144       A Google user
# 81572  dde19e0c-6759-4a9b-afe1-e9b53926326b       A Google user
# 81573  b378cab9-c8b3-44da-895f-43fccf2bdf63       A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ACB-R...
# 1      https://play-lh.googleusercontent.com/a-/ACB-R...
# 2      https://play-lh.googleusercontent.com/a-/ACB-R...
# 3      https://play-lh.googleusercontent.com/a-/ACB-R...
# 4      https://play-lh.googleusercontent.com/a-/ACB-R...
# ...                                                  ...
# 81569  https://play-lh.googleusercontent.com/EGemoI2N...
# 81570  https://play-lh.googleusercontent.com/EGemoI2N...
# 81571  https://play-lh.googleusercontent.com/EGemoI2N...
# 81572  https://play-lh.googleusercontent.com/EGemoI2N...
# 81573  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0      The app is super smooth, very well designed an...      5
# 1      The application is quite fluid and well-design...      5
# 2      This is one of the best app where you can get ...      5
# 3      Amazing app. I have ordered a lot of branded p...      4
# 4      Amazing experience with Fynd. Quality, return ...      5
# ...                                                  ...    ...
# 81569                                              Super      5
# 81570                                               Yoyo      5
# 81571                                                 Ok      3
# 81572                                               None      5
# 81573                                               None      5
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 0                  4                3.2.2 2023-04-06 00:33:02
# 1                  1                3.2.2 2023-04-07 16:11:31
# 2                  0                3.2.2 2023-04-07 14:49:21
# 3                  1                3.2.2 2023-04-06 20:20:22
# 4                  0                3.2.2 2023-04-07 15:04:55
# ...              ...                  ...                 ...
# 81569              0                 None 2016-08-25 16:36:12
# 81570              0                 None 2017-01-16 14:12:12
# 81571              0                 None 2016-11-06 20:56:02
# 81572              0                 None 2017-12-03 12:35:20
# 81573              0                 None 2016-07-29 18:53:05
#
#                                             replyContent           repliedAt  \
# 0      Hey Dolon! Thank you for taking the time to le... 2023-04-10 16:04:43
# 1      Hi! It is delightful to hear such positive wor... 2023-04-10 15:53:29
# 2      Hey Ruma, Thank you very much for sharing your... 2023-04-10 15:53:07
# 3      Hey Tanusree! We're thrilled to hear that you'... 2023-04-10 15:59:54
# 4      Thank you for taking the time to write this re... 2023-04-10 15:53:14
# ...                                                  ...                 ...
# 81569                                               None                 NaT
# 81570                                               None                 NaT
# 81571                                               None                 NaT
# 81572                                               None                 NaT
# 81573                                               None                 NaT
#
#       appVersion
# 0          3.2.2
# 1          3.2.2
# 2          3.2.2
# 3          3.2.2
# 4          3.2.2
# ...          ...
# 81569       None
# 81570       None
# 81571       None
# 81572       None
# 81573       None
#
# [81574 rows x 11 columns]
